# %%
import cv2 as cv
import numpy as np

class ImageProcessing:

    def __init__(image):
        self.image = image

    def blur(self.image):
        #filter = 1
        #filter = np.flip(np.flip(filter, 0), 1)
        #new_image = cv.filter2D(self.image, -1, filter, borderType=cv.BORDER_REFLECT)
        #return new_image
        return

    def black_and_white(image):
        
        image_bw = 0.114*image[:,:,0] + 0.587*image[:,:,1] + 0.299*image[:,:,2]
        
        return image_bw

    #https://medium.com/featurepreneur/colour-filtering-and-colour-pop-effects-using-opencv-python-3ce7d4576140
    def highlight_red():
        return

    def sketch():
        return

    def sad_picasso():
        #https://pythonexamples.org/python-opencv-extract-blue-channel-from-color-image/
        return

    def sketch():
        #https://www.askaswiss.com/2016/01/how-to-create-pencil-sketch-opencv-python.html
        
        return

    def edges():
        return
# Out:
#   File "<ipython-input-1-f607b22e0755>", line 9
#     def blur(self.image):
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Introduction
#
# The purpose of this notebook is to serve as an introduction to image processing and OpenCV. It is meant to serve as an introduction to image processing and computer vision. It is designed to help build intuition when getting started with working with image data.
#
# To get started, we will need:
# - OpenCV: https://opencv.org
# - NumPy: https://numpy.org
# - MatPlotLib: https://matplotlib.org
#
# The reason we use Numpy is that each image is actually a three dimensional numpy array.

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# We can read in a photo using the imread function in OpenCV.

# %%
image = cv.imread("Bosnia.jpg")

# %% [markdown]
# MatPlotLib expects a RGB format, but CV provdes a BGR input, therefore we need to convert it before we plot the image.

# %%
RGB_image = cv.cvtColor(image, cv.COLOR_BGR2RGB)

plt.figure(figsize = (10,15))
plt.imshow(RGB_image)
plt.title('Input Image')
plt.show()

# %%
image = cv.imread("Bosnia.jpg")

# %%
kernel = np.ones((50,50),np.float32)/50**2
image_out = cv.filter2D(image,-1,kernel)

# %%
plt.figure(figsize = (10,15))
plt.imshow(image_out, cmap="gray")
plt.title('Input Image')
plt.show()
